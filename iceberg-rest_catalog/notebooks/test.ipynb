# %%
from pyspark.sql.types import DoubleType, FloatType, LongType, StructType,StructField, StringType

# %%
# %%sql
#
# CREATE NAMESPACE IF NOT EXISTS nyc;
# Out:
# 26/01/28 14:32:42 WARN SparkSession: Using an existing Spark session; only runtime SQL configurations will take effect.
# ++
# ||
# ++
# ++

# %%
schema = StructType([
  StructField("vendor_id", LongType(), True),
  StructField("trip_id", LongType(), True),
  StructField("trip_distance", FloatType(), True),
  StructField("fare_amount", DoubleType(), True),
  StructField("store_and_fwd_flag", StringType(), True)
])

df = spark.createDataFrame([], schema)
df.writeTo("nyc.taxis").create()

# %%
schema = spark.table("nyc.taxis").schema
data = [
    (1, 1000371, 1.8, 15.32, "N"),
    (2, 1000372, 2.5, 22.15, "N"),
    (2, 1000373, 0.9, 9.01, "N"),
    (1, 1000374, 8.4, 42.13, "Y")
  ]
df = spark.createDataFrame(data, schema)
df.writeTo("nyc.taxis").append()

# %%
df = spark.table("nyc.taxis").show()
# Out:
# +---------+-------+-------------+-----------+------------------+
# |vendor_id|trip_id|trip_distance|fare_amount|store_and_fwd_flag|
# +---------+-------+-------------+-----------+------------------+
# |        1|1000371|          1.8|      15.32|                 N|
# |        1|1000371|          1.8|      15.32|                 N|
# |        2|1000372|          2.5|      22.15|                 N|
# |        2|1000373|          0.9|       9.01|                 N|
# |        2|1000372|          2.5|      22.15|                 N|
# |        1|1000374|          8.4|      42.13|                 Y|
# |        2|1000373|          0.9|       9.01|                 N|
# |        1|1000374|          8.4|      42.13|                 Y|
# +---------+-------+-------------+-----------+------------------+

# %%
spark.sql("CREATE NAMESPACE IF NOT EXISTS test")
# Out:
# DataFrame[]

# %%
schema = StructType([
  StructField("vendor_id", LongType(), True),
  StructField("trip_id", LongType(), True),
  StructField("trip_distance", FloatType(), True),
  StructField("fare_amount", DoubleType(), True),
  StructField("store_and_fwd_flag", StringType(), True)
])

df = spark.createDataFrame([], schema)
df.writeTo("test.taxis").create()
